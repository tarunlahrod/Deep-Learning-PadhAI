# %%
import pandas as pd

# %%
! ls
# Out:
#  Debugging.ipynb      mobile_cleaned.csv        Vectors.ipynb
# 'Material provided'  'Pandas tutorials.ipynb'

# %% [markdown]
# #### df is the dataframe

# %%
df = pd.read_csv('mobile_cleaned.csv')

# %% [markdown]
# head() shows first 5 rows

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %% [markdown]
# tail() shows last 5 rows

# %%
df.tail()
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 104        9.4           2                      2.0           2  ...
# 105        7.7           5                      5.0           3  ...
# 106        7.3           2                      5.0           3  ...
# 107        6.9           2                      1.2           3  ...
# 108        7.4           6                      8.0           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %% [markdown]
# To check the datatype of our dataframe, df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# dir(df) shows all the available funcitons under the object df

# %%
dir(df)
# Out:
# ['FM',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
len(df)
# Out:
# 109

# %%
# for the size of data (matrix form)
df.shape
# Out:
# (109, 40)

# %%
# to access a particular location(row) in the data
df.loc[5]
# Out:
# sim_type                                0.0
# aperture                               14.0
# gpu_rank                               55.0
# weight                                179.0
# stand_by_time                         280.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              5.0
# front_camera_resolution                 5.0
# auto_focus                              3.0
# screen_size                             5.5
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       6.0
# os                                      0.0
# phone_height                          150.0
# screen_protection                       5.0
# sim_size                                3.0
# price                                5999.0
# talk_time                              22.0
# video_resolution                      720.0
# ...

# %%
# to create a short dataframe out of this give dataframe
df_short = df[0:10]    #[0,10] 10 is exclusive, so it is 0 to 9

# %%
df_short.shape
# Out:
# (10, 40)

# %%
df_short.head();

# %%
df_short = df[23:29]

# %%
df_thin = df[["stand_by_time", "expandable_memory", "price", "battery_capacity", "is_liked"]]

# %%
df_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
df_thin.shape
# Out:
# (109, 5)

# %%
# get all the devices which are liked
df_liked = df_thin[df_thin["is_liked"] == 1]

# %%
df_liked.shape
# Out:
# (92, 5)

# %%
df_thin["price"].mean()
# Out:
# 19373.211009174312

# %%
df_thin["price"].count()
# Out:
# 109

# %%
df_thin["price"].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin.describe()
# Out:
#        stand_by_time  expandable_memory         price  battery_capacity  \
# count      109.00000         109.000000    109.000000        109.000000
# mean       404.66055         104.513761  19373.211009       2841.779817
# std        176.44206         275.799767  14039.197220        655.003963
# min        160.00000           0.000000   3870.000000       1560.000000
# 25%        264.00000           0.000000   8999.000000       2470.000000
# 50%        360.00000          32.000000  14614.000000       2900.000000
# 75%        500.00000         128.000000  24999.000000       3100.000000
# max       1093.00000        2048.000000  64500.000000       5000.000000
#
#          is_liked
# count  109.000000
# mean     0.844037
# std      0.364496
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
# mean price of all the liked phones
df_thin[df_thin["is_liked"] == 1]["price"].mean()
# Out:
# 19393.239130434784

# %%
# group by
g = df_thin.groupby(["is_liked"])

# %%
for key, df_key in g:
    print(key)
    print(df_key)
# Out:
# 0
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# ...

# %%
df_thin.groupby(["is_liked"]).mean()
# Out:
#           stand_by_time  expandable_memory         price  battery_capacity
# is_liked
# 0            457.235294          68.235294  19264.823529       2874.941176
# 1            394.945652         111.217391  19393.239130       2835.652174

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# To plot grouped by data or the dataframes in general.

# %%
ax = sns.pairplot(df_thin, diag_kind="hist") # hist = histograms

# %%
ax = sns.pairplot(df_thin, diag_kind="hist", hue = "is_liked")
